# %% [raw]
# Imbalanced Dataset
# Cross Validation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('churn.xlsx')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0  7590-VHVEG  Female              0     Yes         No       1           No  \
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection
# 0  No phone service             DSL             No  ...               No  \
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()

# %% [markdown]
# # Null Value check

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# # Balance/Imbalance Check

# %%
Churn = df['Churn'].value_counts()
Churn
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
Y = (5174/(5174+1869))*100
N =(1869/(5174+1869))*100
print(Y,N)
# Out:
# 73.4630129206304 26.536987079369588

# %%
#sns.countplot(df.Churn) #Gives ERROR ""ValueError: could not convert string to float: 'No'""

# %%
df.dropna(inplace=True) #Null value drop

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.drop_duplicates(inplace=True) #duplicate value remove

# %%
df.shape
# Out:
# (7032, 21)

# %%
 df.corr(numeric_only = True)
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# SeniorCitizen        1.000000  0.015205        0.219556      0.102001
# tenure               0.015205  1.000000        0.246852      0.825874
# MonthlyCharges       0.219556  0.246852        1.000000      0.651065
# TotalCharges         0.102001  0.825874        0.651065      1.000000

# %%
plt.figure(figsize=(12,12))
sns.heatmap( df.corr(numeric_only = True),annot=True)
# Out:
# <Axes: >

# %%
sns.countplot(x='gender',hue='Churn',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6352
# No      680
# Name: count, dtype: int64

# %% [markdown]
# # Preprocessing the dataset

# %%
#Encoding,scaling,drop preprocessing technic

# %%
df.drop('customerID',axis=1,inplace=True)

# %%
df.shape
# Out:
# (7032, 20)

# %%
#Label Encoding
from sklearn.preprocessing import LabelEncoder
from pandas.core.dtypes.common import is_numeric_dtype
le = LabelEncoder()

# %%
for col in df.columns:
    if is_numeric_dtype(df[col]):
        continue
    else:
        df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService
# 0       0              0        1           0       1             0  \
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup
# 0              1                0               0             2  \
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract
# 0                 0            0            0                0         0  \
# ...

# %%
x = df.drop('Churn',axis=1)
x
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService
# 0          0              0        1           0       1             0  \
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup
# ...

# %%
y= df[['Churn']]
y
# Out:
#       Churn
# 0         0
# 1         0
# 2         1
# 3         0
# 4         1
# ...     ...
# 7038      0
# 7039      0
# 7040      0
# 7041      1
# 7042      0
#
# [7032 rows x 1 columns]

# %%
print(x.shape,y.shape)
# Out:
# (7032, 19) (7032, 1)

# %%
df.Churn.value_counts()
# Out:
# Churn
# 0    5163
# 1    1869
# Name: count, dtype: int64

# %%
not_churned = (5163/(5163+1869))*100
churned = (1869/(5163+1869))*100

# %%
print('Not Churned',not_churned,'%')
# Out:
# Not Churned 73.42150170648463 %

# %%
print('Churned',churned,'%')
# Out:
# Churned 26.578498293515356 %

# %% [markdown]
# # Synthetic Minority Oversampling Technique(SMOTE)

# %%
# !pip install imblearn

# %%
from imblearn.combine import SMOTETomek
sm = SMOTETomek(random_state=44) #This will used much

# %%
y.value_counts() #before sampling
# Out:
# Churn
# 0        5163
# 1        1869
# Name: count, dtype: int64

# %%
x_1,y_1= sm.fit_resample(x,y)

# %%
y_1.value_counts() #after sampling
# Out:
# Churn
# 0        4785
# 1        4785
# Name: count, dtype: int64

# %% [markdown]
# # NearMiss for under sampling

# %%
from imblearn.under_sampling import NearMiss
nm = NearMiss()

# %%
nm_x,nm_y = nm.fit_resample(x,y)

# %%
nm_y.value_counts()
# Out:
# Churn
# 0        1869
# 1        1869
# Name: count, dtype: int64

# %% [markdown]
# # Over Sampling

# %%
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure
# 0     7590-VHVEG  Female              0     Yes         No       1  \
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...
# 0              No  No phone service             DSL             No  ...  \
# ...

# %%
df2.Churn.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=44)

# %%
ros_x,ros_y = ros.fit_resample(x,y)

# %%
ros_y.value_counts()
# Out:
# Churn
# 0        5163
# 1        5163
# Name: count, dtype: int64

# %% [markdown]
# # Hold out cross validation

# %%
from sklearn.model_selection import train_test_split as tts
xtrain,xtest,ytrain,ytest = tts(ros_x,ros_y,random_state=42)

# %%
xtrain.to_csv('xtrain.csv') #datset to excel

# %%
df
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService
# 0          0              0        1           0       1             0  \
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup
# ...

# %%
train,test = tts(df,train_size=.8,random_state=50) #without separating x,y

# %%
train.head()
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService
# 6403       1              0        1           1      72             1  \
# 1677       1              0        1           1       6             1
# 2723       1              0        0           0      21             1
# 1192       1              0        0           0       7             1
# 3638       0              1        1           0       2             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup
# 6403              2                1               2             2  \
# 1677              2                2               1             1
# 2723              0                2               1             1
# 1192              2                1               0             0
# 3638              0                0               0             2
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract
# ...

# %%
test.head()
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService
# 4460       1              0        1           0      18             1  \
# 733        0              0        1           1      72             1
# 5514       0              0        0           0       1             1
# 5864       0              0        1           0      47             1
# 916        0              1        0           0      23             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup
# 4460              0                1               0             0  \
# 733               2                1               2             0
# 5514              0                0               2             0
# 5864              0                2               1             1
# 916               0                1               2             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract
# ...

# %%
xtrain
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService
# 2724       0              0        0           0       2             1  \
# 5244       1              1        0           0      35             1
# 8403       1              0        0           0      26             1
# 9220       1              0        1           0       9             0
# 9261       0              0        0           0       1             1
# ...      ...            ...      ...         ...     ...           ...
# 5734       0              1        0           0      38             1
# 5191       0              0        0           0      51             1
# 5390       0              0        0           0      50             1
# 860        1              1        1           0      20             1
# 7270       0              1        0           0       2             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup
# ...

# %%
ytrain
# Out:
#       Churn
# 2724      1
# 5244      0
# 8403      1
# 9220      1
# 9261      1
# ...     ...
# 5734      0
# 5191      0
# 5390      0
# 860       1
# 7270      1
#
# [7744 rows x 1 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()

# %%
dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
accuracy = dt.score(xtest,ytest)
accuracy
# Out:
# 0.44188118157365

# %% [markdown]
# # Without Sampling

# %%
xtrain1,xtest1,ytrain1,ytest1 = tts(x,y,test_size=0.3,random_state=42)

# %%
dt.fit(xtrain1,ytrain1)
# Out:
# DecisionTreeRegressor()

# %%
accuracy1 =dt.score(xtest1,ytest1)
accuracy1
# Out:
# -0.4124849553779033

# %% [markdown]
# # K Fold Cross Validation

# %%
from sklearn.model_selection import KFold, cross_val_score, cross_validate
k_fold = KFold(n_splits=4) #n_splits koyta fold korbe by default 5 ta thake

# %%
result_of_every_model = cross_val_score(dt,ros_x,ros_y,cv=k_fold)

# %%
result_of_every_model
# Out:
# array([ 0.04757167, -0.01951222,  0.49327352,  0.        ])

# %%
result_of_every_model.mean()
# Out:
# 0.13033324278138128

# %%
result_of_every_model.max()
# Out:
# 0.4932735206513118

# %%
result_of_every_model.min()
# Out:
# -0.01951221962052596

# %% [markdown]
# # Stratified K Fold Cross Validation

# %%
from sklearn.model_selection import StratifiedKFold

# %%
st = StratifiedKFold(n_splits=4)

# %%
st_accuracy = cross_val_score(dt,ros_x,ros_y,cv=st)
st_accuracy
# Out:
# array([0.44185859, 0.41930244, 0.52574619, 0.62016741])

# %%
st_accuracy.mean()
# Out:
# 0.5017686574165812

# %% [markdown]
# # Leave one out cross validation

# %%
from sklearn.model_selection import LeaveOneOut

# %%
le = LeaveOneOut()

# %%
#le_accuracy = cross_val_score(dt,ros_x,ros_y,cv=le)

# %%
#le_accuracy
#Take too much time because of iteration
